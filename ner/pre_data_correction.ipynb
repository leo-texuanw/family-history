# %%
import pickle as pkl
from os.path import join

DIR = '../objects'

# %%
with open(join(DIR, 'entities.pkl'), 'rb') as pkl_f:
    entities = pkl.load(pkl_f)
with open(join(DIR, 'texts.pkl'), 'rb') as pkl_f:
    texts = pkl.load(pkl_f)

# %% [markdown]
# # Minor offset issues
# - doc_50: full anned as FM
# - doc_157: daughte without r

# %%
# doc_50: full anned as FM
del entities['doc_50'][5]

# %%
# doc_157: daughte without r
# (236, 244, 'FamilyMember', ' daughte')
entities['doc_157'][0] = (237, 245, 'FamilyMember', 'daughter')

# %% [markdown]
# ## Big offset issue
# - doc_169: lost last char
# - doc_59: 3 lost last char
# - doc_66: 4 lost last char
# - doc_4: 10+ 3 offset

# %%
doc = 'doc_169'
idx = 10
for entity in entities[doc][idx:]:
    start = entity[0] - 1
    end = entity[1] - 1
    entities[doc][idx] = (start, end, entity[2], texts[doc][start:end])
    idx += 1

# %%
doc = 'doc_59'
idx = 7
for entity in entities[doc][idx:]:
    start = entity[0] + 1
    end = entity[1] + 1
    entities[doc][idx] = (start, end, entity[2], texts[doc][start:end])
    idx += 1
for entity in entities[doc][7:]:
    print(entity)
# Out:
# (1499, 1517, 'Observation', 'pancreatic abscess')
# (1521, 1542, 'Observation', 'libman sacks etiology')
# (1636, 1642, 'Observation', 'cancer')

# %%
doc = 'doc_66'
idx = 11
for entity in entities[doc][idx:]:
    start = entity[0] + 1
    end = entity[1] + 1
    entities[doc][idx] = (start, end, entity[2], texts[doc][start:end])
    idx += 1
for entity in entities[doc][9:]:
    print(entity)
# Out:
# (596, 609, 'Observation', 'heart disease')
# (620, 626, 'Observation', 'smoker')
# (655, 675, 'FamilyMember', 'maternal grandfather')
# (698, 709, 'Observation', 'alcohol use')
# (798, 818, 'FamilyMember', 'maternal grandmother')
# (827, 840, 'Observation', 'low platelets')

# %%
doc = 'doc_4'
idx = 7

for entity in entities[doc][idx:]:
    start = entity[0] + 3
    end = entity[1] + 3
    entities[doc][idx] = (start, end, entity[2], texts[doc][start:end])
    idx += 1

for entity in entities[doc][7:]:
    print(entity)
# Out:
# (720, 726, 'FamilyMember', 'sister')
# (752, 759, 'Observation', 'Rubeola')
# (787, 793, 'FamilyMember', 'mother')
# (813, 827, 'Observation', 'thymus atrophy')
# (900, 913, 'FamilyMember', 'maternal aunt')
# (933, 947, 'Observation', 'skrjabinemosis')
# (987, 1000, 'FamilyMember', 'maternal aunt')
# (1050, 1064, 'Observation', 'anemia general')
# (1077, 1101, 'FamilyMember', 'Two other maternal aunts')
# (1157, 1163, 'Observation', 'noesis')
# (1189, 1200, 'FamilyMember', 'grandmother')
# (1222, 1234, 'Observation', 'nevus benign')
# (1253, 1264, 'FamilyMember', 'grandfather')
# (1291, 1296, 'Observation', 'maids')
# (1300, 1315, 'Observation', 'timolol allergy')
# (1450, 1456, 'FamilyMember', 'father')
# (1485, 1496, 'Observation', 'anal tumour')
# (1536, 1549, 'FamilyMember', 'paternal aunt')
# (1574, 1587, 'Observation', 'orbital varix')
# (1598, 1611, 'FamilyMember', 'paternal aunt')
# (1653, 1666, 'Observation', 'aspirin abuse')
# (1697, 1710, 'FamilyMember', 'paternal aunt')
# (1741, 1755, 'Observation', 'leprosy neural')
# (1770, 1784, 'FamilyMember', 'paternal uncle')
# (1804, 1815, 'Observation', 'hypermnesia')
# (1841, 1852, 'FamilyMember', 'grandmother')
# (1871, 1895, 'Observation', 'mental disorder caffeine')
# (1914, 1925, 'FamilyMember', 'grandfather')
# (1940, 1954, 'Observation', 'syndrome fraxe')

# %% [markdown]
# # start or end with non-alphabet char issues

# %%
num_entities = 0
for doc, entities_ in entities.items():
    idx = 0
    for entity in entities_:
        num_entities += 1
        start = entity[0]
        end = entity[1]
        ori_len = end - start
        
        content = entity[3].strip()
        after_len = len(content)
        
        if ori_len != after_len:
            start = start + ori_len - len(entity[3].lstrip())
            end = start + after_len
            entities[doc][idx] = (start, end, entity[2], content)
        idx += 1

# %%
entities
# Out:
# {'doc_104': [(315, 323, 'FamilyMember', 'daughter'),
#   (358, 373, 'Observation', 'genetic disease'),
#   (385, 398, 'FamilyMember', 'paternal aunt'),
#   (404, 422, 'Observation', 'nalbuphine allergy'),
#   (446, 459, 'FamilyMember', 'maternal aunt'),
#   (478, 490, 'Observation', 'miscarriages'),
#   (671, 692, 'FamilyMember', 'paternal first cousin'),
#   (698, 711, 'Observation', 'schizophrenia'),
#   (770, 788, 'Observation', 'mental retardation'),
#   (790, 803, 'Observation', 'birth defects'),
#   (805, 826, 'Observation', 'multiple miscarriages'),
#   (830, 844, 'Observation', 'neonatal death')],
#  'doc_167': [(225, 232, 'FamilyMember', 'brother'),
#   (271, 277, 'FamilyMember', 'sister'),
#   (307, 318, 'Observation', 'memory loss'),
#   (325, 331, 'FamilyMember', 'mother'),
#   (346, 349, 'Observation', 'DVT'),
#   (356, 362, 'FamilyMember', 'father')],
#  'doc_145': [(125, 131, 'FamilyMember', 'Mother'),
#   (137, 149, 'Observation', 'hypogonadism'),
#   (152, 165, 'FamilyMember', 'Maternal aunt'),
#   (171, 183, 'Observation', 'brain anoxia'),
#   (186, 200, 'FamilyMember', 'Maternal uncle'),
#   (206, 221, 'Observation', 'gingival tumour'),
#   (250, 270, 'FamilyMember', 'Maternal grandmother'),
#   (276, 289, 'Observation', 'Down syndrome'),
#   (305, 319, 'FamilyMember', 'Maternal uncle'),
#   (338, 357, 'Observation', 'postnatal dysphoria'),
#   (368, 372, 'FamilyMember', 'aunt'),
#   (378, 391, 'Observation', 'Down syndrome'),
#   (411, 417, 'FamilyMember', 'cousin'),
#   (423, 436, 'Observation', 'thigh abscess'),
#   (457, 471, 'FamilyMember', 'Paternal uncle'),
#   (490, 507, 'Observation', 'myasthenia gravis'),
#   (538, 543, 'FamilyMember', 'uncle'),
#   (576, 582, 'Observation', 'cancer'),
#   (595, 611, 'Observation', 'necrosis scrotum')],
#  'doc_4': [(483, 491, 'FamilyMember', 'daughter'),
#   (507, 510, 'FamilyMember', 'son'),
#   (515, 522, 'FamilyMember', 'brother'),
#   (553, 560, 'FamilyMember', 'brother'),
#   (574, 582, 'Observation', 'uvulitis'),
#   (660, 666, 'FamilyMember', 'sister'),
#   (682, 689, 'Observation', 'malaria'),
#   (720, 726, 'FamilyMember', 'sister'),
#   (752, 759, 'Observation', 'Rubeola'),
#   (787, 793, 'FamilyMember', 'mother'),
#   (813, 827, 'Observation', 'thymus atrophy'),
#   (900, 913, 'FamilyMember', 'maternal aunt'),
#   (933, 947, 'Observation', 'skrjabinemosis'),
#   (987, 1000, 'FamilyMember', 'maternal aunt'),
#   (1050, 1064, 'Observation', 'anemia general'),
#   (1077, 1101, 'FamilyMember', 'Two other maternal aunts'),
#   (1157, 1163, 'Observation', 'noesis'),
#   (1189, 1200, 'FamilyMember', 'grandmother'),
#   (1222, 1234, 'Observation', 'nevus benign'),
#   (1253, 1264, 'FamilyMember', 'grandfather'),
#   (1291, 1296, 'Observation', 'maids'),
#   (1300, 1315, 'Observation', 'timolol allergy'),
#   (1450, 1456, 'FamilyMember', 'father'),
#   (1485, 1496, 'Observation', 'anal tumour'),
#   (1536, 1549, 'FamilyMember', 'paternal aunt'),
#   (1574, 1587, 'Observation', 'orbital varix'),
#   (1598, 1611, 'FamilyMember', 'paternal aunt'),
#   (1653, 1666, 'Observation', 'aspirin abuse'),
#   (1697, 1710, 'FamilyMember', 'paternal aunt'),
#   (1741, 1755, 'Observation', 'leprosy neural'),
#   (1770, 1784, 'FamilyMember', 'paternal uncle'),
#   (1804, 1815, 'Observation', 'hypermnesia'),
#   (1841, 1852, 'FamilyMember', 'grandmother'),
#   (1871, 1895, 'Observation', 'mental disorder caffeine'),
#   (1914, 1925, 'FamilyMember', 'grandfather'),
#   (1940, 1954, 'Observation', 'syndrome fraxe')],
#  'doc_86': [(415, 423, 'FamilyMember', 'daughter'),
#   (454, 462, 'Observation', 'dystocia'),
#   (530, 536, 'FamilyMember', 'sister'),
#   (556, 567, 'Observation', 'thyromegaly'),
#   (609, 621, 'Observation', 'heart attack'),
#   (636, 643, 'FamilyMember', 'sisters'),
#   (696, 702, 'Observation', 'stroke'),
#   (707, 714, 'FamilyMember', 'brother'),
#   (735, 757, 'Observation', 'cardiac bypass surgery'),
#   (773, 779, 'FamilyMember', 'mother'),
#   (808, 820, 'Observation', 'heart issues'),
#   (866, 878, 'Observation', 'medicatiions'),
#   (883, 897, 'FamilyMember', 'maternal uncle'),
#   (937, 943, 'Observation', 'asthma'),
#   (948, 961, 'FamilyMember', 'maternal aunt'),
#   (1013, 1026, 'FamilyMember', 'maternal aunt'),
#   (1046, 1063, 'Observation', 'carcinoma bladder'),
#   (1112, 1120, 'Observation', 'dyslexia'),
#   (1131, 1144, 'FamilyMember', 'maternal aunt'),
#   (1177, 1186, 'Observation', 'GE reflux'),
#   (1199, 1205, 'Observation', 'smoker'),
#   (1222, 1242, 'FamilyMember', 'maternal grandmother'),
#   (1341, 1354, 'Observation', 'heart disease'),
#   (1421, 1441, 'FamilyMember', 'maternal grandfather'),
#   (1504, 1510, 'FamilyMember', 'father'),
#   (1529, 1542, 'Observation', 'pelvic cancer'),
#   (1550, 1565, 'FamilyMember', 'paternal uncles'),
#   (1598, 1604, 'Observation', 'cancer'),
#   (1611, 1625, 'FamilyMember', 'paternal aunts'),
#   (1747, 1768, 'FamilyMember', 'paternal grandparents')],
#  'doc_170': [(443, 447, 'FamilyMember', 'sons'),
#   (495, 512, 'Observation', 'dysplasia of anus'),
#   (591, 604, 'Observation', 'heart disease'),
#   (640, 649, 'Observation', 'pneumonia'),
#   (671, 678, 'FamilyMember', 'sisters'),
#   (700, 707, 'FamilyMember', 'brother'),
#   (749, 755, 'Observation', 'cancer'),
#   (762, 768, 'FamilyMember', 'sister'),
#   (821, 834, 'Observation', 'renal disease'),
#   (887, 906, 'Observation', 'leucine sensitivity'),
#   (921, 927, 'FamilyMember', 'mother'),
#   (955, 979, 'Observation', 'neutrophilic hyperplasia'),
#   (1066, 1080, 'FamilyMember', 'maternal uncle'),
#   (1113, 1129, 'FamilyMember', 'maternal cousins'),
#   (1166, 1187, 'FamilyMember', 'maternal grandparents'),
#   (1243, 1249, 'FamilyMember', 'father'),
#   (1268, 1282, 'Observation', 'liver necrosis'),
#   (1291, 1306, 'FamilyMember', 'paternal uncles'),
#   (1358, 1375, 'Observation', 'connective tissue'),
#   (1384, 1400, 'FamilyMember', 'paternal cousins'),
#   (1426, 1432, 'Observation', 'cancer'),
#   (1448, 1459, 'FamilyMember', 'grandmother'),
#   (1506, 1526, 'FamilyMember', 'paternal grandfather'),
#   (1579, 1596, 'Observation', 'gynecologic tumor')],
#  'doc_34': [(334, 337, 'FamilyMember', 'son'),
#   (342, 348, 'Observation', 'cancer'),
#   (575, 593, 'Observation', 'mental retardation'),
#   (595, 608, 'Observation', 'birth defects'),
#   (610, 631, 'Observation', 'multiple miscarriages'),
#   (635, 649, 'Observation', 'neonatal death')],
#  'doc_29': [(243, 246, 'FamilyMember', 'son'),
#   (483, 489, 'FamilyMember', 'sister'),
#   (566, 579, 'Observation', 'enamel caries'),
#   (670, 704, 'FamilyMember', 'two brothers who are half siblings'),
#   (775, 781, 'FamilyMember', 'mother'),
#   (840, 860, 'FamilyMember', 'maternal grandmother'),
#   (905, 912, 'Observation', 'cholera'),
#   (1532, 1550, 'Observation', 'neoplasms vascular'),
#   (1552, 1573, 'Observation', 'learning disabilities'),
#   (1578, 1591, 'Observation', 'psych problem'),
#   (1630, 1651, 'Observation', 'multiple miscarriages'),
#   (1690, 1696, 'FamilyMember', 'mother'),
#   (1710, 1722, 'Observation', 'miscarriages'),
#   (1838, 1844, 'Observation', 'asthma')],
#  'doc_143': [(212, 232, 'FamilyMember', 'paternal grandfather'),
#   (261, 269, 'Observation', 'uricemia'),
#   (276, 296, 'FamilyMember', 'paternal grandmother'),
#   (320, 329, 'Observation', 'pneumonia'),
#   (372, 378, 'FamilyMember', 'father'),
#   (392, 413, 'Observation', 'brown mclean syndrome'),
#   (417, 429, 'Observation', 'quadraplegia'),
#   (431, 442, 'Observation', 'neck lipoma'),
#   (448, 464, 'Observation', 'meninges sarcoma'),
#   (471, 485, 'FamilyMember', 'paternal uncle'),
#   (494, 504, 'Observation', 'cystocoele'),
#   (544, 549, 'FamilyMember', 'uncle'),
#   (575, 599, 'FamilyMember', '3 paternal first cousins'),
#   (625, 645, 'FamilyMember', 'maternal grandfather'),
#   (672, 685, 'Observation', 'urachal cysts'),
#   (698, 729, 'Observation', 'cardiomyopathy amyloid etiology'),
#   (736, 756, 'FamilyMember', 'maternal grandmother'),
#   (779, 787, 'Observation', 'basiloma'),
#   (794, 804, 'Observation', 'body tinea'),
#   (850, 856, 'FamilyMember', 'mother'),
#   (870, 884, 'Observation', 'vagina sarcoma'),
#   (889, 898, 'Observation', 'odontomas'),
#   (913, 928, 'FamilyMember', 'maternal uncles'),
#   (964, 978, 'FamilyMember', 'maternal aunts'),
#   (1010, 1032, 'FamilyMember', 'maternal first cousins'),
#   (1067, 1075, 'FamilyMember', 'brothers'),
#   (1147, 1150, 'FamilyMember', 'Son'),
#   (1164, 1168, 'Observation', 'CCHF'),
#   (1173, 1179, 'Observation', 'cancer'),
#   (1182, 1185, 'FamilyMember', 'Son'),
#   (1198, 1215, 'Observation', 'gastritis biliary'),
#   (1220, 1226, 'Observation', 'cancer'),
#   (1229, 1232, 'FamilyMember', 'Son'),
#   (1245, 1251, 'Observation', 'cancer'),
#   (1254, 1262, 'FamilyMember', 'Daughter'),
#   (1282, 1312, 'Observation', 'febrile mucocutaneous syndrome'),
#   (1315, 1323, 'FamilyMember', 'Daughter')],
#  'doc_139': [(317, 323, 'FamilyMember', 'mother'),
#   (342, 353, 'Observation', 'gastroliths'),
#   (385, 398, 'Observation', 'aphasia broca'),
#   (402, 420, 'Observation', 'fever typhogastric'),
#   (463, 469, 'FamilyMember', 'father'),
#   (490, 496, 'Observation', 'cancer'),
#   (506, 525, 'Observation', 'pancreatitis fungal'),
#   (644, 660, 'Observation', 'allergy sunshine'),
#   (662, 681, 'Observation', 'neurosis depressive'),
#   (686, 704, 'Observation', 'metastatic disease'),
#   (724, 745, 'FamilyMember', 'maternal half brother'),
#   (777, 791, 'Observation', 'disease graves'),
#   (827, 835, 'FamilyMember', 'brothers'),
#   (849, 855, 'FamilyMember', 'sister'),
#   (868, 875, 'FamilyMember', 'brother'),
#   (889, 904, 'Observation', 'dubinis disease'),
#   (909, 928, 'Observation', 'gonorrhea recurrent'),
#   (943, 950, 'FamilyMember', 'brother'),
#   (969, 988, 'Observation', 'papillary carcinoma'),
#   (995, 1001, 'FamilyMember', 'sister'),
#   (1015, 1026, 'Observation', 'nettle rash'),
#   (1049, 1057, 'FamilyMember', 'children'),
#   (1071, 1075, 'FamilyMember', 'sons'),
#   (1103, 1120, 'Observation', 'connective tissue'),
#   (1231, 1249, 'Observation', 'familial polyposis'),
#   (1253, 1280, 'Observation', 'mental behavioral disorders'),
#   (1296, 1304, 'FamilyMember', 'daughter'),
#   (1335, 1369, 'Observation', 'germ cell tumour ovarian recurrent')],
#  'doc_130': [(74, 80, 'FamilyMember', 'father'),
#   (97, 111, 'Observation', 'never been ill'),
#   (170, 177, 'FamilyMember', 'sisters'),
#   (184, 192, 'FamilyMember', 'brothers'),
#   (235, 242, 'Observation', 'cancers'),
#   (248, 254, 'FamilyMember', 'mother'),
#   (278, 284, 'Observation', 'stroke'),
#   (299, 306, 'FamilyMember', 'brother'),
#   (312, 318, 'FamilyMember', 'sister'),
#   (330, 337, 'Observation', 'malaria'),
#   (413, 419, 'FamilyMember', 'sister'),
#   (435, 442, 'Observation', 'cancers'),
#   (569, 577, 'FamilyMember', 'children'),
#   (590, 593, 'FamilyMember', 'son'),
#   (704, 712, 'FamilyMember', 'daughter'),
#   (721, 729, 'FamilyMember', 'daughter'),
#   (755, 768, 'Observation', 'hydrocephalus'),
#   (790, 807, 'Observation', 'delleman syndrome')],
#  'doc_16': [(258, 271, 'FamilyMember', 'paternal aunt'),
#   (284, 296, 'Observation', 'heart murmur'),
#   (442, 456, 'FamilyMember', 'paternal uncle'),
#   (840, 858, 'Observation', 'neoplasm choroidal'),
#   (860, 881, 'Observation', 'osteochondrodysplasia'),
#   (883, 896, 'Observation', 'histomoniases'),
#   (898, 922, 'Observation', 'familial retinoblastomas'),
#   (933, 945, 'Observation', 'heart murmur'),
#   (947, 960, 'Observation', 'thrombopenias'),
#   (970, 988, 'Observation', 'hypertensionlabile')],
#  'doc_124': [(229, 236, 'FamilyMember', 'brother'),
#   (316, 322, 'FamilyMember', 'father'),
#   (327, 333, 'FamilyMember', 'mother'),
#   (804, 822, 'Observation', 'mental retardation'),
#   (824, 845, 'Observation', 'learning disabilities'),
#   (847, 860, 'Observation', 'birth defects'),
#   (862, 885, 'Observation', 'multiple pregnancy loss'),
#   (887, 898, 'Observation', 'stillbirths'),
#   (900, 913, 'Observation', 'infant deaths'),
#   (918, 933, 'Observation', 'cystic fibrosis')],
#  'doc_150': [(0, 3, 'FamilyMember', 'Dad'),
#   (22, 37, 'Observation', 'uterus adhesion'),
#   (39, 48, 'Observation', 'akithisia'),
#   (50, 62, 'Observation', 'dextrocardia'),
#   (64, 87, 'Observation', 'prophylactic mastectomy'),
#   (100, 124, 'Observation', 'suprarenal insufficiency'),
#   (126, 138, 'Observation', 'lymphocoeles'),
#   (162, 173, 'Observation', 'lung cancer'),
#   (175, 185, 'Observation', 'basal cell'),
#   (188, 191, 'FamilyMember', 'Mom'),
#   (224, 236, 'Observation', 'sacral ulcer'),
#   (238, 249, 'Observation', 'memory loss'),
#   (251, 265, 'Observation', 'neonatal death'),
#   (277, 288, 'Observation', 'cystdermoid'),
#   (300, 311, 'Observation', 'leukopenias'),
#   (315, 323, 'FamilyMember', 'brothers'),
#   (345, 360, 'Observation', 'pityriasis alba'),
#   (375, 387, 'Observation', 'sinus cancer'),
#   (391, 398, 'FamilyMember', 'sisters'),
#   (454, 469, 'Observation', 'pan microscopic'),
#   (505, 517, 'Observation', 'lung fibroma'),
#   (570, 580, 'Observation', 'stomatitis')],
#  'doc_92': [(225, 231, 'FamilyMember', 'sister'),
#   (248, 254, 'FamilyMember', 'sister'),
#   (315, 321, 'FamilyMember', 'mother'),
#   (334, 340, 'FamilyMember', 'father')],
#  'doc_80': [(332, 338, 'FamilyMember', 'father'),
#   (384, 409, 'Observation', 'chronic pulmonary disease'),
#   (440, 448, 'FamilyMember', 'children'),
#   (454, 462, 'FamilyMember', 'daughter'),
#   (475, 478, 'FamilyMember', 'son'),
#   (545, 552, 'FamilyMember', 'brother'),
#   (562, 571, 'Observation', 'depressed'),
#   (593, 602, 'FamilyMember', 'daughters'),
#   (621, 628, 'FamilyMember', 'brother'),
#   (647, 656, 'Observation', 'alcoholic'),
#   (674, 677, 'FamilyMember', 'son'),
#   (684, 690, 'FamilyMember', 'father'),
#   (728, 734, 'Observation', 'smoker'),
#   (752, 761, 'Observation', 'depressed'),
#   (771, 777, 'FamilyMember', 'mother'),
#   (815, 821, 'Observation', 'smoker'),
#   (935, 941, 'Observation', 'asthma'),
#   (1118, 1136, 'Observation', 'mental retardation'),
#   (1138, 1159, 'Observation', 'learning disabilities'),
#   (1164, 1177, 'Observation', 'birth defects'),
#   (1202, 1233, 'Observation', 'multiple miscarriages or babies'),
#   (1244, 1253, 'Observation', 'stillborn'),
#   (1257, 1267, 'Observation', 'died early'),
#   (1295, 1301, 'Observation', 'cancer')],
#  'doc_154': [(4, 17, 'FamilyMember', 'maternal aunt'),
#   (22, 35, 'Observation', 'low platelets'),
#   (146, 152, 'FamilyMember', 'mother'),
#   (173, 180, 'FamilyMember', 'sisters'),
#   (200, 213, 'Observation', 'low platelets'),
#   (241, 249, 'FamilyMember', 'children'),
#   (274, 280, 'Observation', 'cancer'),
#   (305, 311, 'FamilyMember', 'mother')],
#  'doc_21': [(235, 238, 'FamilyMember', 'son'),
#   (318, 324, 'FamilyMember', 'sister'),
#   (368, 375, 'FamilyMember', 'brother'),
#   (398, 404, 'FamilyMember', 'father'),
#   (434, 440, 'FamilyMember', 'mother'),
#   (480, 492, 'Observation', 'heart murmur'),
#   (500, 512, 'Observation', 'cancers anal'),
#   (530, 544, 'FamilyMember', 'maternal uncle'),
#   (641, 646, 'FamilyMember', 'aunts'),
#   (660, 671, 'Observation', 'waardenburg'),
#   (705, 713, 'Observation', 'dwarfism'),
#   (754, 765, 'Observation', 'lung cancer'),
#   (792, 803, 'FamilyMember', 'grandmother'),
#   (808, 821, 'Observation', 'blood disease'),
#   (851, 862, 'FamilyMember', 'grandfather'),
#   (872, 880, 'Observation', 'fainting'),
#   (1203, 1221, 'Observation', 'cutaneous syphilis'),
#   (1223, 1244, 'Observation', 'associative dysphasia'),
#   (1249, 1262, 'Observation', 'family ataxia'),
#   (1296, 1308, 'Observation', 'ocular tumor'),
#   (1413, 1419, 'Observation', 'asthma')],
#  'doc_42': [(0, 13, 'FamilyMember', 'Paternal aunt'),
#   (19, 33, 'Observation', 'uterine cancer'),
#   (78, 98, 'FamilyMember', 'paternal grandfather'),
#   (120, 126, 'Observation', 'cancer'),
#   (175, 193, 'FamilyMember', 'paternal relatives'),
#   (281, 288, 'Observation', 'cancers'),
#   (311, 324, 'FamilyMember', 'three sisters'),
#   (329, 342, 'FamilyMember', 'five brothers'),
#   (356, 363, 'FamilyMember', 'sisters'),
#   (374, 398, 'Observation', 'encephalitis periaxialis'),
#   (402, 410, 'Observation', 'seizures'),
#   (798, 805, 'FamilyMember', 'brother')],
#  'doc_93': [(4, 17, 'FamilyMember', 'maternal aunt'),
#   (22, 35, 'Observation', 'low platelets'),
#   (173, 180, 'FamilyMember', 'sisters'),
#   (200, 213, 'Observation', 'low platelets'),
#   (274, 281, 'Observation', 'cancers'),
#   (305, 311, 'FamilyMember', 'mother'),
#   (379, 383, 'Observation', 'fall')],
#  'doc_66': [(200, 206, 'FamilyMember', 'sister'),
#   (246, 267, 'FamilyMember', 'two healthy daughters'),
#   (318, 326, 'FamilyMember', 'two sons'),
#   (377, 383, 'FamilyMember', 'mother'),
#   (403, 416, 'Observation', 'low platelets'),
#   (438, 455, 'Observation', 'alzheimer disease'),
#   (483, 501, 'Observation', 'multiple sclerosis'),
#   (530, 544, 'FamilyMember', 'maternal uncle'),
#   (570, 581, 'Observation', 'hypermnesia'),
#   (596, 609, 'Observation', 'heart disease'),
#   (620, 626, 'Observation', 'smoker'),
#   (655, 675, 'FamilyMember', 'maternal grandfather'),
#   (698, 709, 'Observation', 'alcohol use'),
#   (798, 818, 'FamilyMember', 'maternal grandmother'),
#   (827, 840, 'Observation', 'low platelets')],
#  'doc_79': [(225, 228, 'FamilyMember', 'son'),
#   (283, 286, 'FamilyMember', 'son'),
#   (302, 310, 'FamilyMember', 'daughter'),
#   (371, 378, 'FamilyMember', 'brother'),
#   (395, 401, 'FamilyMember', 'sister'),
#   (607, 613, 'FamilyMember', 'mother'),
#   (636, 646, 'Observation', 'hemophilia'),
#   (653, 659, 'FamilyMember', 'father'),
#   (678, 695, 'Observation', 'diabetes mellitus'),
#   (744, 750, 'Observation', 'smoker')],
#  'doc_158': [(225, 232, 'FamilyMember', 'sisters'),
#   (303, 310, 'FamilyMember', 'brother'),
#   (328, 335, 'FamilyMember', 'parents'),
#   (367, 373, 'FamilyMember', 'mother'),
#   (383, 389, 'FamilyMember', 'father'),
#   (466, 474, 'FamilyMember', 'daughter'),
#   (690, 708, 'Observation', 'mental retardation'),
#   (710, 731, 'Observation', 'benign tumor of ovary'),
#   (736, 749, 'Observation', 'cardiac polyp'),
#   (868, 874, 'Observation', 'cancer')],
#  'doc_74': [(361, 367, 'FamilyMember', 'mother'),
#   (419, 433, 'Observation', 'blood pressure'),
#   (525, 531, 'Observation', 'asthma'),
#   (589, 595, 'Observation', 'cancer'),
#   (721, 731, 'FamilyMember', '2 children'),
#   (735, 738, 'FamilyMember', 'son'),
#   (818, 826, 'FamilyMember', 'daughter'),
#   (862, 873, 'Observation', 'colonoscopy')],
#  'doc_50': [(438, 446, 'FamilyMember', 'children'),
#   (453, 456, 'FamilyMember', 'son'),
#   (482, 488, 'Observation', 'wolman'),
#   (490, 513, 'Observation', 'deficiency pyridoxamine'),
#   (519, 533, 'Observation', 'cittotaeniosis'),
#   (560, 573, 'FamilyMember', 'half siblings'),
#   (560, 573, 'FamilyMember', 'half siblings'),
#   (565, 573, 'FamilyMember', 'siblings'),
#   (565, 573, 'FamilyMember', 'siblings'),
#   (599, 605, 'Observation', 'apeded'),
#   (647, 653, 'FamilyMember', 'mother'),
#   (673, 686, 'Observation', 'comas hepatic'),
#   (756, 776, 'FamilyMember', 'maternal grandmother'),
#   (796, 804, 'Observation', 'osselets'),
#   (850, 870, 'FamilyMember', 'maternal grandfather'),
#   (964, 970, 'FamilyMember', 'father'),
#   (1012, 1034, 'Observation', 'umbilical cord anomaly'),
#   (1059, 1074, 'Observation', 'hemochromatosis'),
#   (1094, 1106, 'Observation', 'hyperthermia'),
#   (1131, 1147, 'Observation', 'fungal infection'),
#   (1152, 1167, 'Observation', 'pineal syndrome'),
#   (1184, 1204, 'FamilyMember', 'paternal grandmother'),
#   (1220, 1226, 'Observation', 'cancer'),
#   (1317, 1332, 'FamilyMember', 'paternal cousin'),
#   (1368, 1381, 'Observation', 'heart attacks')],
#  'doc_91': [(432, 440, 'Observation', 'leukemia'),
#   (471, 487, 'Observation', 'insomnia primary'),
#   (523, 541, 'Observation', 'collagen arthritis'),
#   (701, 719, 'Observation', 'mental retardation'),
#   (721, 742, 'Observation', 'learning disabilities'),
#   (744, 757, 'Observation', 'birth defects'),
#   (759, 780, 'Observation', 'multiple miscarriages'),
#   (782, 795, 'Observation', 'infant deaths'),
#   (797, 804, 'Observation', 'cancers')],
#  'doc_43': [(104, 110, 'FamilyMember', 'father'),
#   (136, 142, 'Observation', 'cancer'),
#   (154, 178, 'Observation', 'peribronchial pneumonia.'),
#   (193, 212, 'Observation', 'factor S deficiency'),
#   (217, 230, 'FamilyMember', 'paternal aunt'),
#   (249, 262, 'Observation', 'planus lichen'),
#   (273, 286, 'FamilyMember', 'paternal aunt'),
#   (313, 319, 'Observation', 'corbus'),
#   (330, 350, 'FamilyMember', 'paternal grandfather'),
#   (392, 412, 'FamilyMember', 'paternal grandmother'),
#   (437, 449, 'Observation', 'heart issues'),
#   (495, 501, 'Observation', 'cancer'),
#   (550, 556, 'FamilyMember', 'cousin'),
#   (605, 611, 'Observation', 'cancer'),
#   (617, 623, 'FamilyMember', 'mother'),
#   (643, 655, 'Observation', 'cyesiophobia'),
#   (712, 724, 'FamilyMember', 'six children')],
#  'doc_178': [(9, 15, 'FamilyMember', 'father'),
#   (31, 41, 'Observation', 'overweight'),
#   (160, 168, 'Observation', 'diabetes'),
#   (172, 190, 'Observation', 'bone marrow cancer'),
#   (224, 248, 'Observation', 'gonococcal perihepatitis'),
#   (268, 278, 'Observation', 'metabolism'),
#   (280, 296, 'Observation', 'diarrhea anxiety'),
#   (301, 324, 'Observation', 'stage I lentigo maligna'),
#   (335, 341, 'FamilyMember', 'mother')],
#  'doc_49': [(218, 221, 'FamilyMember', 'son'),
#   (312, 319, 'FamilyMember', 'brother'),
#   (375, 381, 'FamilyMember', 'sister'),
#   (428, 439, 'Observation', 'miscarriage'),
#   (448, 454, 'FamilyMember', 'mother'),
#   (480, 486, 'FamilyMember', 'father'),
#   (886, 904, 'Observation', 'polyp inflammatory'),
#   (906, 927, 'Observation', 'segmental dysfunction'),
#   (932, 945, 'Observation', 'jung syndrome'),
#   (970, 991, 'Observation', 'parathyroid disorders'),
#   (1063, 1069, 'Observation', 'cancer')],
#  'doc_54': [(461, 476, 'FamilyMember', 'three daughters'),
#   (481, 489, 'FamilyMember', 'six sons'),
#   (517, 524, 'FamilyMember', 'brother'),
#   (585, 616, 'Observation', 'oesophageal neoplasm metastatic'),
#   (658, 665, 'FamilyMember', 'brother'),
#   (740, 746, 'FamilyMember', 'mother'),
#   (836, 848, 'Observation', 'pineal tumor'),
#   (853, 866, 'FamilyMember', 'maternal aunt'),
#   (897, 910, 'FamilyMember', 'maternal aunt'),
#   (961, 988, 'Observation', 'cardiac problems infarction'),
#   (1015, 1023, 'FamilyMember', 'two sons'),
#   (1048, 1056, 'FamilyMember', 'daughter'),
#   (1069, 1084, 'Observation', 'staccato speech'),
#   (1098, 1112, 'FamilyMember', 'maternal uncle'),
#   (1164, 1184, 'FamilyMember', 'maternal grandfather'),
#   (1210, 1221, 'Observation', 'skin cancer'),
#   (1238, 1258, 'FamilyMember', 'maternal grandmother'),
#   (1281, 1305, 'Observation', 'congestive heart failure'),
#   (1311, 1338, 'Observation', 'acromioclavicular infection'),
#   (1394, 1429, 'FamilyMember', 'maternal maternal great-grandmother'),
#   (1449, 1461, 'Observation', 'heart attack'),
#   (1524, 1530, 'FamilyMember', 'father'),
#   (1570, 1576, 'Observation', 'fetish'),
#   (1597, 1612, 'Observation', 'psychosis manic'),
#   (1614, 1630, 'Observation', 'emotional crisis'),
#   (1632, 1644, 'Observation', 'uterus myoma'),
#   (1658, 1675, 'Observation', 'fecalith appendix'),
#   (1680, 1693, 'FamilyMember', 'maternal aunt'),
#   (1712, 1723, 'Observation', 'skin cancer'),
#   (1740, 1746, 'Observation', 'smoker'),
#   (1763, 1783, 'FamilyMember', 'paternal grandmother'),
#   (1798, 1814, 'Observation', 'albright disease'),
#   (1834, 1854, 'FamilyMember', 'maternal grandfather'),
#   (1873, 1889, 'Observation', 'sternal neoplasm')],
#  'doc_24': [(280, 300, 'FamilyMember', 'maternal grandfather'),
#   (319, 332, 'Observation', 'gastric tumor'),
#   (792, 812, 'FamilyMember', 'maternal grandmother'),
#   (832, 844, 'Observation', 'hysterectomy'),
#   (1521, 1527, 'FamilyMember', 'mother'),
#   (1547, 1560, 'Observation', 'cysticercosis'),
#   (1605, 1617, 'Observation', 'hysterectomy'),
#   (1650, 1663, 'FamilyMember', 'maternal aunt'),
#   (1679, 1691, 'Observation', 'hysterectomy'),
#   (1696, 1711, 'Observation', 'urethral cancer'),
#   (1739, 1752, 'Observation', 'heart disease'),
#   (1773, 1786, 'FamilyMember', 'maternal aunt'),
#   (1815, 1835, 'Observation', 'lesch nyhan syndrome'),
#   (1853, 1868, 'FamilyMember', "aunt's daughter"),
#   (1911, 1922, 'Observation', 'ileocolitis'),
#   (1971, 1984, 'FamilyMember', 'maternal aunt'),
#   (2023, 2044, 'FamilyMember', 'maternal first cousin'),
#   (2073, 2081, 'Observation', 'haglunds'),
#   (2178, 2193, 'FamilyMember', "aunt's daughter"),
#   (2222, 2234, 'Observation', 'colon cancer'),
#   (2241, 2265, 'FamilyMember', 'remaining three children'),
#   (2372, 2378, 'Observation', 'asthma'),
#   (2394, 2414, 'FamilyMember', 'paternal grandfather'),
#   (2434, 2455, 'Observation', 'thiamine deficiencies'),
#   (2462, 2482, 'FamilyMember', 'paternal grandmother'),
#   (2517, 2523, 'FamilyMember', 'father'),
#   (2542, 2563, 'Observation', 'puerperal salpingitis'),
#   (2706, 2712, 'FamilyMember', 'sister'),
#   (2752, 2771, 'Observation', 'factor S deficiency'),
#   (2778, 2792, 'FamilyMember', 'three brothers'),
#   (2827, 2833, 'Observation', 'cancer'),
#   (2891, 2894, 'FamilyMember', 'son'),
#   (2923, 2955, 'Observation', 'oral glyceryl trinitrate allergy'),
#   (2970, 2973, 'FamilyMember', 'son'),
#   (3001, 3013, 'Observation', 'sinus testis'),
#   (3018, 3032, 'Observation', 'ekbom syndrome'),
#   (3062, 3093, 'Observation', 'laryngeal sarcomatoid carcinoma'),
#   (3248, 3256, 'FamilyMember', 'daughter')],
#  'doc_60': [(234, 269, 'FamilyMember', 'paternal maternal great grandmother'),
#   (289, 301, 'Observation', 'brain cancer'),
#   (369, 375, 'FamilyMember', 'father'),
#   (408, 421, 'FamilyMember', 'paternal aunt'),
#   (430, 444, 'FamilyMember', 'paternal uncle'),
#   (493, 498, 'Observation', 'colon'),
#   (502, 515, 'Observation', 'other cancers'),
#   (508, 514, 'Observation', 'cancer'),
#   (727, 745, 'Observation', 'mental retardation'),
#   (747, 768, 'Observation', 'learning disabilities'),
#   (770, 783, 'Observation', 'birth defects'),
#   (820, 832, 'Observation', 'miscarriages')],
#  'doc_41': [(446, 452, 'FamilyMember', 'mother'),
#   (480, 493, 'Observation', 'ulcer bladder'),
#   (510, 530, 'FamilyMember', 'maternal grandfather'),
#   (550, 564, 'Observation', 'hypothyroidism'),
#   (607, 614, 'Observation', 'smoking'),
#   (667, 673, 'Observation', 'alalia'),
#   (689, 695, 'FamilyMember', 'father'),
#   (724, 739, 'Observation', 'type 2 diabetes'),
#   (777, 788, 'Observation', 'hypermnesia'),
#   (811, 825, 'FamilyMember', 'paternal aunts'),
#   (832, 846, 'FamilyMember', 'paternal uncle'),
#   (887, 898, 'Observation', 'alcohol use'),
#   (946, 976, 'Observation', 'extramembranous glomerulopathy'),
#   (1088, 1096, 'Observation', 'fainting'),
#   (1174, 1189, 'FamilyMember', 'maternal cousin'),
#   (1220, 1232, 'Observation', 'heart murmur'),
#   (1260, 1280, 'FamilyMember', 'paternal grandmother'),
#   (1299, 1305, 'Observation', 'asthma'),
#   (1312, 1332, 'FamilyMember', 'paternal grandfather'),
#   (1370, 1381, 'Observation', 'fever oroya'),
#   (1613, 1636, 'Observation', 'vulval neoplasms benign'),
#   (1640, 1665, 'Observation', 'malignant clitoris tumour')],
#  'doc_36': [(33, 53, 'FamilyMember', 'maternal grandmother'),
#   (85, 95, 'Observation', 'lipoidemia'),
#   (104, 124, 'FamilyMember', 'maternal grandfather'),
#   (373, 389, 'Observation', 'thyroid problems'),
#   (401, 404, 'FamilyMember', 'Dad'),
#   (454, 463, 'Observation', 'stressors'),
#   (466, 486, 'FamilyMember', 'Paternal grandmother'),
#   (522, 551, 'Observation', 'infiltrating ductal carcinoma'),
#   (577, 587, 'Observation', 'hemophilia'),
#   (602, 616, 'FamilyMember', 'paternal uncle'),
#   (635, 642, 'Observation', 'alcohol'),
#   (647, 652, 'Observation', 'drugs'),
#   (660, 669, 'FamilyMember', "man's son"),
#   (821, 841, 'FamilyMember', 'paternal grandfather'),
#   (848, 860, 'Observation', 'nail disease'),
#   (995, 1011, 'Observation', 'genital dwarfism'),
#   (1013, 1026, 'Observation', 'borna disease'),
#   (1031, 1035, 'Observation', 'CCHF'),
#   (1037, 1040, 'FamilyMember', 'Mom'),
#   (1103, 1115, 'Observation', 'chronic pain'),
#   (1121, 1125, 'Observation', 'skin'),
#   (1130, 1144, 'Observation', 'brain problems')],
#  'doc_11': [(99, 119, 'FamilyMember', 'maternal grandfather'),
#   (128, 141, 'Observation', 'cysticercosis'),
#   (173, 193, 'FamilyMember', 'maternal grandmother'),
#   (210, 227, 'Observation', 'keratitis actinic'),
#   (238, 251, 'Observation', 'heart disease'),
#   (264, 284, 'Observation', 'dermatitis acneiform'),
#   (409, 415, 'FamilyMember', 'mother'),
#   (436, 443, 'Observation', 'anthrax'),
#   (462, 469, 'Observation', 'Jejunum'),
#   (474, 488, 'FamilyMember', 'maternal uncle'),
#   (509, 516, 'Observation', 'cancers'),
#   (528, 534, 'FamilyMember', 'child,'),
#   (537, 545, 'FamilyMember', 'daughter'),
#   (563, 570, 'Observation', 'cancers'),
#   (585, 596, 'FamilyMember', 'grandfather'),
#   (628, 639, 'FamilyMember', 'grandmother'),
#   (717, 723, 'FamilyMember', 'father'),
#   (738, 749, 'Observation', 'hypermnesia'),
#   (759, 765, 'Observation', 'smoked'),
#   (778, 798, 'FamilyMember', 'paternal half-sister'),
#   (842, 864, 'FamilyMember', 'Maternal half-brothers'),
#   (899, 906, 'Observation', 'cancers'),
#   (922, 926, 'FamilyMember', 'sons'),
#   (964, 971, 'Observation', 'cholera')],
#  'doc_118': [(212, 219, 'FamilyMember', 'brother'),
#   (237, 263, 'Observation', 'recurrent thyroid problems'),
#   (345, 351, 'FamilyMember', 'father'),
#   (345, 351, 'FamilyMember', 'father'),
#   (385, 391, 'FamilyMember', 'mother'),
#   (410, 422, 'Observation', 'hypertension')],
#  'doc_18': [(262, 268, 'FamilyMember', 'mother'),
#   (337, 355, 'Observation', 'psoriasis nummular'),
#   (531, 544, 'FamilyMember', 'maternal aunt'),
#   (586, 604, 'Observation', 'malignant smallpox'),
#   (814, 820, 'FamilyMember', 'sister'),
#   (881, 893, 'Observation', 'hypertension'),
#   (916, 923, 'FamilyMember', 'brother'),
#   (964, 979, 'Observation', 'cervix metritis'),
#   (1172, 1195, 'FamilyMember', 'two additional brothers'),
#   (1231, 1237, 'FamilyMember', 'sister'),
#   (1355, 1362, 'Observation', 'malaria')],
#  'doc_176': [(21, 36, 'FamilyMember', "mother's father"),
#   (52, 68, 'Observation', 'endosalpingiosis'),
#   (142, 153, 'Observation', 'hypermnesia'),
#   (164, 171, 'FamilyMember', 'brother'),
#   (195, 222, 'Observation', 'presbyopia with astigmatism'),
#   (245, 251, 'FamilyMember', 'sister'),
#   (264, 283, 'Observation', 'atrial fibrillation'),
#   (333, 346, 'Observation', 'iron disorder'),
#   (351, 355, 'Observation', 'COPD'),
#   (362, 365, 'FamilyMember', 'dad'),
#   (370, 391, 'Observation', 'esophageal infections'),
#   (396, 400, 'Observation', 'COPD'),
#   (414, 420, 'FamilyMember', 'mother'),
#   (432, 448, 'Observation', 'coronary disease'),
#   (472, 481, 'Observation', 'pneumonia')],
#  'doc_156': [(228, 236, 'FamilyMember', 'daughter'),
#   (374, 381, 'FamilyMember', 'brother'),
#   (474, 480, 'FamilyMember', 'mother'),
#   (510, 533, 'Observation', 'syndrome hemiparaplegic'),
#   (587, 593, 'FamilyMember', 'father'),
#   (611, 619, 'Observation', 'imbecile'),
#   (629, 642, 'Observation', 'enamel caries')],
#  'doc_2': [(307, 313, 'FamilyMember', 'father'),
#   (327, 331, 'Observation', 'abpe'),
#   (340, 360, 'Observation', 'testosterone allergy'),
#   (375, 390, 'Observation', 'abuse laxatives'),
#   (460, 470, 'Observation', 'crop bound'),
#   (474, 492, 'Observation', 'aortocaval fistula'),
#   (498, 504, 'FamilyMember', 'mother'),
#   (541, 549, 'FamilyMember', 'siblings'),
#   (564, 572, 'Observation', 'bird pox'),
#   (666, 672, 'Observation', 'keshan'),
#   (727, 734, 'FamilyMember', 'brother'),
#   (751, 761, 'Observation', 'nails soft'),
#   (846, 854, 'FamilyMember', 'brothers'),
#   (891, 911, 'FamilyMember', 'two teenage children')],
#  'doc_23': [(104, 115, 'FamilyMember', 'grandfather'),
#   (135, 149, 'Observation', 'gangliosidosis'),
#   (164, 175, 'FamilyMember', 'grandmother'),
#   (199, 211, 'Observation', 'phycomycosis'),
#   (291, 297, 'FamilyMember', 'father'),
#   (315, 325, 'Observation', 'pachygyria'),
#   (356, 366, 'Observation', 'hemophilia'),
#   (466, 471, 'FamilyMember', 'aunts'),
#   (501, 517, 'Observation', 'surface dyslexia'),
#   (549, 577, 'FamilyMember', 'three paternal first cousins'),
#   (915, 926, 'FamilyMember', 'grandfather'),
#   (937, 947, 'Observation', 'foot ulcer'),
#   (956, 976, 'Observation', 'meningitis recurrent'),
#   (1001, 1012, 'FamilyMember', 'grandmother'),
#   (1080, 1086, 'FamilyMember', 'mother'),
#   (1114, 1133, 'Observation', 'papillary carcinoma'),
#   (1185, 1203, 'FamilyMember', 'two maternal aunts'),
#   (1226, 1239, 'Observation', 'pineoblastoma'),
#   (1270, 1275, 'FamilyMember', 'uncle'),
#   (1307, 1333, 'FamilyMember', 'two maternal first cousins'),
#   (1422, 1428, 'FamilyMember', 'sister'),
#   (1467, 1471, 'FamilyMember', 'twin'),
#   (1481, 1491, 'Observation', 'hemophilia'),
#   (1502, 1524, 'Observation', 'paranasal sinus cancer')],
#  'doc_57': [(243, 249, 'FamilyMember', 'father'),
#   (353, 367, 'Observation', 'groin melanoma'),
#   (418, 424, 'FamilyMember', 'mother'),
#   (521, 533, 'Observation', 'eye problems'),
#   (562, 576, 'FamilyMember', 'three brothers'),
#   (581, 592, 'FamilyMember', 'two sisters'),
#   (636, 650, 'Observation', 'groin melanoma'),
#   (773, 793, 'FamilyMember', 'maternal grandfather'),
#   (834, 847, 'Observation', 'low platelets'),
#   (966, 986, 'FamilyMember', 'maternal half-sister'),
#   (1050, 1058, 'FamilyMember', 'daughter'),
#   (1069, 1077, 'Observation', 'clubfoot')],
#  'doc_140': [(0, 20, 'FamilyMember', 'Paternal grandfather'),
#   (25, 37, 'Observation', 'hypertension'),
#   (46, 52, 'FamilyMember', 'Father'),
#   (57, 72, 'Observation', 'type 2 diabetes'),
#   (86, 100, 'FamilyMember', 'Paternal uncle'),
#   (107, 127, 'Observation', 'fingerprint myopathy'),
#   (148, 156, 'FamilyMember', 'brothers'),
#   (166, 173, 'FamilyMember', 'sisters'),
#   (191, 199, 'FamilyMember', 'siblings'),
#   (209, 221, 'Observation', 'thyroid lump'),
#   (251, 263, 'Observation', 'hypertension'),
#   (275, 281, 'FamilyMember', 'mother'),
#   (324, 367, 'Observation', 'leukemia pediatric acute lymphocytic t cell'),
#   (387, 395, 'FamilyMember', 'children'),
#   (437, 440, 'FamilyMember', 'son'),
#   (449, 457, 'Observation', 'acute MI'),
#   (462, 482, 'Observation', 'giant cell pneumonia'),
#   (503, 522, 'Observation', 'rhinoconjunctivitis'),
#   (555, 581, 'Observation', 'loss function of labyrinth')],
#  'doc_9': [(227, 247, 'FamilyMember', 'maternal grandfather'),
#   (364, 376, 'Observation', 'fsc lymphoma'),
#   (402, 421, 'Observation', 'infectionbitespider'),
#   (478, 498, 'FamilyMember', 'maternal grandmother'),
#   (519, 531, 'Observation', 'hallucinosis'),
#   (546, 566, 'Observation', 'cyclic schizophrenia'),
#   (588, 607, 'Observation', 'renal pelvis tumour'),
#   (612, 628, 'Observation', 'high cholesterol'),
#   (676, 682, 'FamilyMember', 'mother'),
#   (714, 728, 'FamilyMember', 'Paternal uncle'),
#   (766, 781, 'Observation', 'retina disorder'),
#   (788, 801, 'FamilyMember', 'maternal aunt'),
#   (834, 848, 'FamilyMember', 'maternal uncle'),
#   (867, 899, 'Observation', 'histoplasma capsulatum infection'),
#   (902, 916, 'FamilyMember', 'Maternal uncle'),
#   (951, 975, 'FamilyMember', '2 maternal first cousins'),
#   (1001, 1021, 'FamilyMember', 'paternal grandfather'),
#   (1067, 1078, 'FamilyMember', 'grandmother'),
#   (1092, 1104, 'Observation', 'wind sucking'),
#   (1169, 1187, 'Observation', 'nephrosis cholemic'),
#   (1214, 1229, 'Observation', 'hyoid myoclonus'),
#   (1312, 1318, 'FamilyMember', 'father'),
#   (1354, 1370, 'FamilyMember', '3 paternal aunts'),
#   (1375, 1392, 'FamilyMember', '4 paternal uncles'),
#   (1483, 1507, 'FamilyMember', '3 paternal first cousins'),
#   (1530, 1537, 'FamilyMember', 'Brother'),
#   (1619, 1627, 'FamilyMember', 'Daughter'),
#   (1649, 1652, 'FamilyMember', 'Son')],
#  'doc_85': [(255, 261, 'FamilyMember', 'mother'),
#   (281, 294, 'Observation', 'thyroid toxic'),
#   (338, 348, 'Observation', 'cystitides'),
#   (363, 376, 'FamilyMember', 'maternal aunt'),
#   (420, 433, 'Observation', 'dermanyssosis'),
#   (464, 468, 'FamilyMember', 'aunt'),
#   (488, 500, 'Observation', 'spinal tumor'),
#   (584, 604, 'FamilyMember', 'maternal grandmother'),
#   (645, 658, 'Observation', 'heart disease'),
#   (971, 977, 'Observation', 'cancer'),
#   (1084, 1092, 'FamilyMember', 'brothers'),
#   (1133, 1142, 'FamilyMember', 'daughters'),
#   (1168, 1171, 'FamilyMember', 'son')],
#  'doc_157': [(237, 245, 'FamilyMember', 'daughter'),
#   (265, 268, 'FamilyMember', 'son'),
#   (329, 335, 'FamilyMember', 'sister'),
#   (352, 359, 'FamilyMember', 'brother'),
#   (402, 408, 'FamilyMember', 'mother'),
#   (441, 454, 'FamilyMember', 'maternal aunt'),
#   (476, 517, 'Observation', 'choroid plexus papilloma fourth ventricle'),
#   (595, 601, 'FamilyMember', 'father'),
#   (633, 640, 'FamilyMember', 'brother'),
#   (656, 667, 'Observation', 'GI problems'),
#   (675, 693, 'Observation', 'pharynx cellulitis'),
#   (751, 757, 'FamilyMember', 'nephew'),
#   (763, 771, 'Observation', 'mastitis'),
#   (1364, 1377, 'Observation', 'blepharelosis'),
#   (1379, 1392, 'Observation', 'moral deficit'),
#   (1394, 1412, 'Observation', 'anomaly integument'),
#   (1416, 1437, 'Observation', 'cellulitis of pharynx')],
#  'doc_161': [(121, 135, 'FamilyMember', 'maternal uncle'),
#   (175, 190, 'Observation', 'atr astigmatism'),
#   (316, 322, 'Observation', 'krabbe'),
#   (762, 769, 'FamilyMember', 'brother'),
#   (806, 821, 'Observation', 'skin syphilitic'),
#   (883, 889, 'Observation', 'krabbe'),
#   (973, 991, 'Observation', 'viral meningitides'),
#   (1025, 1039, 'Observation', 'blood pressure'),
#   (1201, 1214, 'Observation', 'abscess joint'),
#   (1306, 1313, 'FamilyMember', 'brother'),
#   (1413, 1421, 'FamilyMember', 'daughter'),
#   (1439, 1442, 'FamilyMember', 'son')],
#  'doc_12': [(339, 359, 'FamilyMember', 'paternal grandfather'),
#   (409, 429, 'FamilyMember', 'paternal grandmother'),
#   (453, 459, 'Observation', 'asthma'),
#   (525, 531, 'FamilyMember', 'father'),
#   (600, 615, 'Observation', 'asthma colliers'),
#   (620, 628, 'Observation', 'pancoast'),
#   (661, 675, 'Observation', 'Uterine corbus'),
#   (680, 686, 'Observation', 'canker'),
#   (753, 768, 'Observation', 'torus palatinus'),
#   (863, 877, 'Observation', 'pigmented skin'),
#   (880, 894, 'FamilyMember', 'Paternal uncle'),
#   (937, 950, 'FamilyMember', 'Paternal aunt'),
#   (996, 1016, 'FamilyMember', 'maternal grandfather'),
#   (1046, 1067, 'Observation', 'genital lichen planus'),
#   (1078, 1086, 'Observation', 'embolism'),
#   (1104, 1113, 'Observation', 'IMMPaCtte'),
#   (1120, 1140, 'FamilyMember', 'maternal grandmother'),
#   (1169, 1175, 'Observation', 'asthma'),
#   (1214, 1227, 'Observation', 'amebic eczema'),
#   (1278, 1284, 'FamilyMember', 'mother'),
#   (1305, 1319, 'Observation', 'blood pressure'),
#   (1347, 1361, 'FamilyMember', 'Maternal uncle'),
#   (1406, 1421, 'Observation', 'urethral corbus'),
#   (1424, 1445, 'FamilyMember', 'Maternal first cousin'),
#   (1476, 1489, 'Observation', 'heart attacks'),
#   (1502, 1509, 'FamilyMember', 'Sisters'),
#   (1569, 1577, 'FamilyMember', 'Children'),
#   (1637, 1643, 'FamilyMember', 'father'),
#   (1648, 1654, 'FamilyMember', 'mother')],
#  'doc_164': [(172, 192, 'FamilyMember', 'Maternal grandfather'),
#   (197, 208, 'FamilyMember', 'grandmother'),
#   (270, 276, 'FamilyMember', 'mother'),
#   (292, 307, 'Observation', 'nipple neoplasm'),
#   (403, 423, 'Observation', 'eardrum inflammation'),
#   (482, 496, 'FamilyMember', 'maternal aunts'),
#   (524, 530, 'FamilyMember', 'cousin'),
#   (541, 560, 'Observation', 'shortness of breath'),
#   (583, 602, 'Observation', 'retrosternal hernia'),
#   (608, 614, 'FamilyMember', 'father'),
#   (724, 744, 'FamilyMember', 'Maternal half sister'),
#   (753, 778, 'Observation', 'gingival pregnancy tumour'),
#   (844, 866, 'FamilyMember', 'paternal half brothers')],
#  'doc_115': [(242, 246, 'FamilyMember', 'sons'),
#   (323, 329, 'FamilyMember', 'sister'),
#   (358, 369, 'Observation', 'thalassemia'),
#   (407, 422, 'Observation', 'type 2 diabetes'),
#   (474, 481, 'FamilyMember', 'brother'),
#   (555, 561, 'FamilyMember', 'mother'),
#   (581, 605, 'Observation', 'malignant blood disorder'),
#   (638, 655, 'Observation', 'babesia infection'),
#   (720, 738, 'Observation', 'multiple sclerosis'),
#   (743, 756, 'FamilyMember', 'maternal aunt'),
#   (788, 805, 'Observation', 'alzheimer disease'),
#   (885, 901, 'Observation', 'strep infections'),
#   (1058, 1064, 'FamilyMember', 'father'),
#   (1069, 1089, 'Observation', 'emphysema paraseptal'),
#   (1165, 1180, 'Observation', 'aortic dilation'),
#   (1185, 1198, 'FamilyMember', 'paternal aunt'),
#   (1236, 1256, 'Observation', 'disorder micturition'),
#   (1300, 1320, 'FamilyMember', 'paternal grandmother'),
#   (1345, 1365, 'Observation', 'disorder micturition')],
#  'doc_162': [(40, 59, 'Observation', 'chemical dependence'),
#   (69, 93, 'Observation', 'present alcohol/drug use'),
#   (214, 236, 'Observation', 'demyelinating diseases'),
#   (260, 267, 'FamilyMember', 'brother'),
#   (272, 285, 'FamilyMember', 'paternal aunt'),
#   (326, 333, 'Observation', 'suicide'),
#   (440, 448, 'Observation', 'fainting'),
#   (549, 559, 'Observation', 'overweight'),
#   (567, 574, 'FamilyMember', 'brother'),
#   (590, 603, 'Observation', 'renal disease'),
#   (619, 626, 'Observation', 'obesity'),
#   (669, 676, 'FamilyMember', 'cousins')],
#  'doc_59': [(338, 342, 'FamilyMember', 'male'),
#   (432, 438, 'FamilyMember', 'sister'),
#   (491, 498, 'FamilyMember', 'brother'),
#   (568, 574, 'FamilyMember', 'mother'),
#   (588, 594, 'FamilyMember', 'father'),
#   (624, 637, 'FamilyMember', 'paternal aunt'),
#   (652, 655, 'FamilyMember', 'son'),
#   (1499, 1517, 'Observation', 'pancreatic abscess'),
#   (1521, 1542, 'Observation', 'libman sacks etiology'),
#   (1636, 1642, 'Observation', 'cancer')],
#  'doc_138': [(18, 38, 'FamilyMember', 'paternal grandfather'),
#   (48, 71, 'Observation', 'prophylactic mastectomy'),
#   (77, 91, 'FamilyMember', 'paternal uncle'),
#   (100, 115, 'Observation', 'Marfan syndrome'),
#   (149, 155, 'FamilyMember', 'father'),
#   (161, 184, 'Observation', 'prophylactic mastectomy'),
#   (217, 225, 'Observation', 'diabetes'),
#   (227, 230, 'FamilyMember', 'Mom'),
#   (247, 257, 'Observation', 'hemophilia'),
#   (259, 266, 'Observation', 'cholera'),
#   (272, 275, 'Observation', 'DKA'),
#   (304, 330, 'Observation', 'recurrent malignant tumour'),
#   (342, 350, 'Observation', 'dementia'),
#   (355, 373, 'Observation', 'multiple sclerosis'),
#   (375, 382, 'FamilyMember', 'Brother'),
#   (399, 403, 'Observation', 'CCHF'),
#   (434, 445, 'FamilyMember', 'grandmother'),
#   (462, 482, 'Observation', 'deficiency endocrine'),
#   (487, 491, 'Observation', 'CCHF'),
#   (502, 513, 'FamilyMember', 'grandfather'),
#   (530, 540, 'Observation', 'colorblind'),
#   (542, 557, 'Observation', 'cardiac disease'),
#   (563, 571, 'Observation', 'melanoma'),
#   (624, 638, 'Observation', 'heart problems'),
#   (640, 647, 'Observation', 'malaria'),
#   (653, 657, 'Observation', 'COPD')],
#  'doc_6': [(253, 261, 'FamilyMember', 'daughter'),
#   (284, 287, 'FamilyMember', 'son'),
#   (330, 337, 'FamilyMember', 'brother'),
#   (391, 402, 'Observation', 'legs ulcers'),
#   (405, 424, 'FamilyMember', 'Four other brothers'),
#   (482, 488, 'FamilyMember', 'mother'),
#   (496, 514, 'Observation', 'vitreous syneresis'),
#   (592, 603, 'Observation', 'myocarditis'),
#   (645, 654, 'Observation', 'emphysema'),
#   (687, 700, 'FamilyMember', 'maternal aunt'),
#   (729, 742, 'Observation', 'viral illness'),
#   (772, 784, 'Observation', 'gaze apraxia'),
#   (818, 831, 'FamilyMember', 'maternal aunt'),
#   (860, 878, 'Observation', 'behcet arthritides'),
#   (919, 932, 'FamilyMember', 'maternal aunt'),
#   (961, 981, 'Observation', 'salmonella pneumonia'),
#   (1056, 1081, 'FamilyMember', 'five other maternal aunts'),
#   (1086, 1113, 'FamilyMember', 'three other maternal uncles'),
#   (1126, 1133, 'Observation', 'halzoun'),
#   (1137, 1143, 'Observation', 'pigbel'),
#   (1164, 1171, 'Observation', 'phorias'),
#   (1179, 1186, 'FamilyMember', 'cousins'),
#   (1202, 1222, 'FamilyMember', 'maternal grandmother'),
#   (1251, 1258, 'Observation', 'perthes'),
#   (2240, 2260, 'FamilyMember', 'maternal grandfather'),
#   (2280, 2293, 'Observation', 'deviation sex'),
#   (2321, 2333, 'Observation', 'skin disease'),
#   (2385, 2391, 'Observation', 'heller'),
#   (3274, 3280, 'Observation', 'oguchi'),
#   (3296, 3302, 'FamilyMember', 'father'),
#   (3323, 3329, 'Observation', 'corbus'),
#   (3360, 3375, 'Observation', 'reflux duodenal'),
#   (3380, 3393, 'FamilyMember', 'paternal aunt'),
#   (3422, 3436, 'Observation', 'bile nephrosis'),
#   (3571, 3584, 'FamilyMember', 'paternal aunt'),
#   (3614, 3627, 'Observation', 'atrophic hair'),
#   (3657, 3669, 'Observation', 'heart blocks'),
#   (3674, 3687, 'FamilyMember', 'paternal aunt'),
#   (3716, 3730, 'Observation', 'fryns syndrome'),
#   (3745, 3759, 'FamilyMember', 'paternal uncle'),
#   (3763, 3769, 'Observation', 'smoker'),
#   (3778, 3794, 'Observation', 'thinking reduced'),
#   (3823, 3836, 'Observation', 'timber tongue'),
#   (3857, 3871, 'FamilyMember', 'paternal uncle'),
#   (3875, 3881, 'Observation', 'smoker'),
#   (3890, 3906, 'Observation', 'tarsal coalition'),
#   (3935, 3949, 'Observation', 'carcinofibroma'),
#   (3985, 3996, 'FamilyMember', 'grandmother'),
#   (4010, 4033, 'Observation', 'muscle tissue neoplasms'),
#   (4160, 4166, 'Observation', 'dawson')],
#  'doc_1': [(222, 230, 'FamilyMember', 'daughter'),
#   (246, 249, 'FamilyMember', 'son'),
#   (300, 312, 'FamilyMember', 'Two brothers'),
#   (346, 352, 'FamilyMember', 'sister'),
#   (368, 391, 'Observation', 'duplication 2q syndrome'),
#   (416, 441, 'Observation', 'grade 2 ileum obstruction'),
#   (452, 472, 'Observation', 'arboviral infections'),
#   (505, 511, 'FamilyMember', 'sister'),
#   (582, 602, 'Observation', 'conduction disorders'),
#   (640, 646, 'FamilyMember', 'mother'),
#   (677, 701, 'Observation', 'bile duct adenocarcinoma'),
#   (736, 757, 'Observation', 'disorders of meninges'),
#   (812, 824, 'Observation', 'lump of skin'),
#   (835, 857, 'Observation', 'neoplasm maligprostate'),
#   (906, 920, 'FamilyMember', 'maternal uncle'),
#   (949, 964, 'Observation', 'ovarian failure'),
#   (1064, 1070, 'Observation', 'hurler'),
#   (1086, 1092, 'FamilyMember', 'father'),
#   (1113, 1119, 'Observation', 'men ii'),
#   (1172, 1180, 'FamilyMember', 'paternal'),
#   (1187, 1193, 'FamilyMember', 'cousin'),
#   (1232, 1249, 'Observation', 'phaeochromocytoma'),
#   (1260, 1268, 'FamilyMember', 'paternal'),
#   (1275, 1281, 'FamilyMember', 'cousin'),
#   (1318, 1335, 'Observation', 'choreic dysphonia'),
#   (1362, 1382, 'FamilyMember', 'paternal grandfather'),
#   (1402, 1414, 'Observation', 'ear melanoma'),
#   (1539, 1545, 'Observation', 'herpes')],
#  'doc_97': [(329, 349, 'FamilyMember', 'Maternal grandfather'),
#   (378, 398, 'FamilyMember', 'Maternal grandmother'),
#   (435, 441, 'FamilyMember', 'Mother'),
#   (458, 474, 'Observation', 'severe nosebleed'),
#   (479, 490, 'Observation', 'thalassemia'),
#   (552, 565, 'FamilyMember', 'Maternal aunt'),
#   (595, 610, 'FamilyMember', 'Maternal uncles'),
#   (622, 636, 'Observation', 'stomach cancer'),
#   (641, 655, 'Observation', 'hypothyroidism'),
#   (680, 702, 'FamilyMember', 'maternal first cousins'),
#   (726, 746, 'FamilyMember', 'Paternal grandfather'),
#   (766, 781, 'Observation', 'type 2 diabetes'),
#   (812, 832, 'FamilyMember', 'Paternal grandmother'),
#   (857, 888, 'Observation', 'esophago pharyngeal diverticula'),
#   (897, 905, 'Observation', 'fainting'),
#   (908, 914, 'FamilyMember', 'Father'),
#   (935, 951, 'Observation', 'larynx carcinoma'),
#   (1013, 1018, 'FamilyMember', 'uncle'),
#   (1063, 1069, 'FamilyMember', 'cousin'),
#   (1091, 1099, 'FamilyMember', 'Siblings'),
#   (1121, 1129, 'Observation', 'ischemia'),
#   (1138, 1159, 'Observation', 'post traumatic eczema'),
#   (1184, 1205, 'Observation', 'splenic sequestration')],
#  'doc_40': [(288, 294, 'FamilyMember', 'sister'),
#   (323, 331, 'Observation', 'yaba pox'),
#   (402, 414, 'Observation', 'angiolipomas'),
#   (507, 514, 'FamilyMember', 'brother'),
#   (528, 544, 'Observation', 'peanut allergies'),
#   (551, 564, 'FamilyMember', 'two daughters'),
#   (594, 601, 'FamilyMember', 'brother'),
#   (670, 676, 'FamilyMember', 'mother'),
#   (690, 706, 'Observation', 'severe nosebleed'),
#   (759, 783, 'Observation', 'malignant gangliogliomas'),
#   (827, 846, 'FamilyMember', 'Two maternal uncles'),
#   (853, 866, 'FamilyMember', 'maternal aunt'),
#   (886, 892, 'Observation', 'lichen'),
#   (908, 924, 'FamilyMember', 'maternal cousins'),
#   (943, 949, 'Observation', 'xeroma'),
#   (966, 987, 'FamilyMember', 'maternal grandparents'),
#   (1009, 1016, 'Observation', 'cholera'),
#   (1032, 1038, 'FamilyMember', 'father'),
#   (1057, 1064, 'Observation', 'cholera'),
#   (1087, 1096, 'Observation', 'allergies'),
#   (1101, 1115, 'Observation', 'cerebral palsy'),
#   (1120, 1134, 'FamilyMember', 'paternal uncle'),
# ...
#   (612, 618, 'FamilyMember', 'cousin'),
#   (627, 650, 'Observation', 'recurrent heart disease'),
#   (688, 695, 'FamilyMember', 'cousins'),
#   (704, 716, 'Observation', 'fever uremic'),
#   (963, 969, 'FamilyMember', 'sister'),
#   (994, 1008, 'Observation', 'prolapse colon'),
#   (1182, 1204, 'FamilyMember', 'maternal first cousins'),
#   (1230, 1243, 'Observation', 'fungus eczema')],
#  'doc_148': [(446, 452, 'FamilyMember', 'sister'),
#   (520, 526, 'FamilyMember', 'mother'),
#   (543, 572, 'Observation', 'elevated lipoprotein A levels'),
#   (579, 585, 'FamilyMember', 'father'),
#   (608, 620, 'Observation', 'polyp rectum'),
#   (1381, 1399, 'Observation', 'hemoglobinopathies'),
#   (1401, 1422, 'Observation', 'vaginitis trichomonal'),
#   (1427, 1440, 'Observation', 'xerophthalmia'),
#   (1474, 1486, 'Observation', 'miscarriages'),
#   (1507, 1531, 'Observation', 'still born or died early')],
#  'doc_56': [(205, 211, 'FamilyMember', 'father'),
#   (232, 244, 'Observation', 'colon cancer'),
#   (260, 266, 'Observation', 'dermal'),
#   (307, 319, 'Observation', 'coma insulin'),
#   (345, 367, 'FamilyMember', 'siblings of the father'),
#   (381, 404, 'Observation', 'submucosal cleft palate'),
#   (409, 422, 'FamilyMember', 'paternal aunt'),
#   (432, 446, 'Observation', 'uterine cancer'),
#   (614, 621, 'FamilyMember', 'cousins'),
#   (662, 676, 'Observation', 'autism torsion'),
#   (692, 698, 'FamilyMember', 'mother'),
#   (728, 750, 'Observation', 'umbilical cord anomaly'),
#   (760, 772, 'Observation', 'edema cornea'),
#   (801, 813, 'Observation', 'hypertension'),
#   (815, 826, 'Observation', 'colon spasm'),
#   (829, 846, 'Observation', 'alzheimer disease'),
#   (852, 862, 'Observation', 'depression'),
#   (901, 914, 'Observation', 'myriapodiasis'),
#   (946, 954, 'FamilyMember', 'siblings'),
#   (963, 978, 'Observation', 'kidney problems'),
#   (1042, 1048, 'FamilyMember', 'sister'),
#   (1072, 1095, 'Observation', 'neoplasm of the urethra'),
#   (1111, 1126, 'Observation', 'porphyria acute'),
#   (1142, 1155, 'Observation', 'grawitz tumor'),
#   (1208, 1222, 'FamilyMember', 'three children'),
#   (1273, 1281, 'FamilyMember', 'daughter'),
#   (1295, 1311, 'Observation', 'chorea syndromes'),
#   (1359, 1372, 'Observation', 'lufts disease'),
#   (1379, 1387, 'FamilyMember', 'children')],
#  'doc_174': [(224, 232, 'FamilyMember', 'daughter'),
#   (270, 276, 'FamilyMember', 'sister'),
#   (326, 332, 'FamilyMember', 'sister'),
#   (387, 393, 'FamilyMember', 'sister'),
#   (454, 468, 'Observation', 'pyelitis acute'),
#   (476, 482, 'FamilyMember', 'mother'),
#   (510, 516, 'FamilyMember', 'father'),
#   (528, 536, 'Observation', 'mousepox'),
#   (1013, 1031, 'Observation', 'mental retardation'),
#   (1033, 1054, 'Observation', 'learning disabilities'),
#   (1058, 1071, 'Observation', 'birth defects'),
#   (1096, 1117, 'Observation', 'multiple miscarriages'),
#   (1138, 1161, 'Observation', 'stillborn or died early'),
#   (1189, 1195, 'Observation', 'cancer')],
#  'doc_160': [(335, 341, 'FamilyMember', 'mother'),
#   (361, 373, 'Observation', 'heart attack'),
#   (455, 463, 'FamilyMember', 'children'),
#   (524, 542, 'Observation', 'large gastric mass'),
#   (544, 557, 'Observation', 'fever chitral'),
#   (559, 580, 'Observation', 'haematoporphyrinaemia'),
#   (584, 598, 'Observation', 'pulp gangrenes')],
#  'doc_62': [(36, 39, 'FamilyMember', 'dad'),
#   (45, 58, 'Observation', 'abscessdental'),
#   (60, 72, 'Observation', 'edema retina'),
#   (74, 88, 'Observation', 'seizureabsence'),
#   (90, 96, 'Observation', 'asthma'),
#   (102, 113, 'FamilyMember', 'grandparent'),
#   (124, 131, 'Observation', 'malaria'),
#   (137, 143, 'FamilyMember', 'sister'),
#   (208, 216, 'Observation', 'dyslexia'),
#   (218, 232, 'Observation', 'hyperlipidemia'),
#   (234, 246, 'Observation', 'heart issues'),
#   (272, 283, 'Observation', 'blood clots'),
#   (317, 333, 'Observation', 'thyroid problems'),
#   (375, 378, 'FamilyMember', 'Mom'),
#   (435, 448, 'Observation', 'heart disease'),
#   (468, 481, 'FamilyMember', 'maternal aunt'),
#   (516, 529, 'Observation', 'heart disease'),
#   (535, 541, 'FamilyMember', 'sister'),
#   (582, 592, 'Observation', 'alcoholism'),
#   (594, 601, 'FamilyMember', 'Brother')],
#  'doc_37': [(449, 462, 'FamilyMember', 'maternal aunt'),
#   (491, 504, 'Observation', 'nickel eczema'),
#   (538, 551, 'FamilyMember', 'maternal aunt'),
#   (580, 593, 'Observation', 'low platelets'),
#   (608, 622, 'FamilyMember', 'maternal uncle'),
#   (642, 648, 'Observation', 'asthma'),
#   (655, 663, 'FamilyMember', 'daughter'),
#   (687, 700, 'Observation', 'schizophrenia'),
#   (762, 776, 'Observation', 'hypothyroidism'),
#   (792, 812, 'FamilyMember', 'maternal grandfather'),
#   (850, 856, 'Observation', 'corbus'),
#   (873, 893, 'FamilyMember', 'maternal grandmother'),
#   (913, 921, 'Observation', 'dwarfism'),
#   (944, 956, 'Observation', 'brain corbus'),
#   (1104, 1112, 'FamilyMember', 'daughter'),
#   (1132, 1145, 'Observation', 'enamel caries'),
#   (1346, 1352, 'FamilyMember', 'mother'),
#   (1381, 1394, 'Observation', 'vulvar corbus'),
#   (1409, 1423, 'FamilyMember', 'paternal uncle'),
#   (1447, 1458, 'Observation', 'lung corbus'),
#   (1469, 1483, 'FamilyMember', 'paternal uncle'),
#   (1503, 1515, 'Observation', 'acute chorea'),
#   (1547, 1567, 'FamilyMember', 'paternal grandfather'),
#   (1626, 1638, 'Observation', 'desmoplastic'),
#   (1644, 1665, 'Observation', 'learning disabilities'),
#   (1811, 1818, 'Observation', 'cholera'),
#   (1822, 1845, 'Observation', 'maxillary antrum tumour')],
#  'doc_44': [(444, 453, 'FamilyMember', 'daughters'),
#   (470, 473, 'FamilyMember', 'son'),
#   (494, 500, 'FamilyMember', 'sister'),
#   (522, 528, 'FamilyMember', 'mother'),
#   (553, 567, 'Observation', 'acute disorder'),
#   (572, 585, 'Observation', 'low platelets'),
#   (600, 613, 'FamilyMember', 'maternal aunt'),
#   (633, 646, 'Observation', 'pineoblastoma'),
#   (709, 713, 'FamilyMember', 'sons'),
#   (718, 731, 'FamilyMember', 'one daughter,'),
#   (750, 757, 'Observation', 'cholera'),
#   (765, 795, 'Observation', 'complications after childbirth'),
#   (809, 829, 'FamilyMember', 'maternal grandmother'),
#   (849, 863, 'Observation', 'hypothyroidism'),
#   (915, 935, 'FamilyMember', 'maternal grandfather'),
#   (955, 967, 'Observation', 'hypertension'),
#   (1010, 1016, 'FamilyMember', 'father'),
#   (1036, 1047, 'Observation', 'thalassemia'),
#   (1078, 1084, 'Observation', 'smoker'),
#   (1103, 1117, 'FamilyMember', 'paternal uncle'),
#   (1141, 1158, 'Observation', 'angelman syndrome'),
#   (1205, 1219, 'FamilyMember', 'paternal uncle'),
#   (1250, 1267, 'Observation', 'oligodendroglioma'),
#   (1289, 1303, 'FamilyMember', 'paternal aunts'),
#   (1349, 1362, 'FamilyMember', 'paternal aunt'),
#   (1387, 1406, 'Observation', 'acute schizophrenic'),
#   (1420, 1440, 'FamilyMember', 'paternal grandmother'),
#   (1461, 1469, 'Observation', 'lameness'),
#   (1479, 1499, 'FamilyMember', 'paternal grandfather'),
#   (1522, 1528, 'Observation', 'asthma'),
#   (1532, 1544, 'Observation', 'heart issues'),
#   (1619, 1642, 'Observation', 'prophylactic mastectomy'),
#   (1646, 1653, 'Observation', 'cholera')],
#  'doc_19': [(240, 248, 'FamilyMember', 'daughter'),
#   (258, 264, 'Observation', 'cancer'),
#   (281, 294, 'FamilyMember', 'three sisters'),
#   (301, 307, 'FamilyMember', 'sister'),
#   (387, 398, 'Observation', 'gynatresias'),
#   (409, 415, 'FamilyMember', 'sister'),
#   (525, 537, 'Observation', 'osteoporosis'),
#   (552, 558, 'FamilyMember', 'father'),
#   (572, 592, 'Observation', 'salmonella infection'),
#   (599, 616, 'Observation', 'kanamycin allergy'),
#   (653, 658, 'FamilyMember', 'uncle'),
#   (686, 694, 'Observation', 'aneurysm'),
#   (917, 935, 'Observation', 'isoflurane allergy'),
#   (937, 950, 'Observation', 'haygarth node'),
#   (952, 973, 'Observation', 'barium pneumoconiosis'),
#   (977, 991, 'Observation', 'adenomathyroid')],
#  'doc_117': [(224, 230, 'FamilyMember', 'sister'),
#   (259, 283, 'Observation', 'anomalies nervous system'),
#   (318, 339, 'Observation', 'myocardial infarction'),
#   (344, 356, 'Observation', 'dextrocardia'),
#   (367, 373, 'FamilyMember', 'sister'),
#   (445, 462, 'Observation', 'delleman syndrome'),
#   (478, 484, 'FamilyMember', 'mother'),
#   (512, 518, 'Observation', 'cancer'),
#   (809, 821, 'Observation', 'dextrocardia'),
#   (909, 929, 'FamilyMember', 'maternal grandmother'),
#   (949, 962, 'Observation', 'low platelets'),
#   (1305, 1311, 'FamilyMember', 'father'),
#   (1333, 1344, 'Observation', 'tonsillitis'),
#   (1357, 1372, 'Observation', 'aortic dilation')],
#  'doc_147': [(504, 510, 'FamilyMember', 'female'),
#   (593, 600, 'FamilyMember', 'brother'),
#   (653, 660, 'FamilyMember', 'brother'),
#   (730, 736, 'FamilyMember', 'sister'),
#   (763, 769, 'FamilyMember', 'mother'),
#   (783, 795, 'Observation', 'heart murmur'),
#   (819, 825, 'FamilyMember', 'father'),
#   (830, 846, 'Observation', 'stupor catatonic'),
#   (1346, 1364, 'Observation', 'manifest hyperopia'),
#   (1366, 1387, 'Observation', 'paratesticular lipoma'),
#   (1392, 1405, 'Observation', 'ulcers rodent'),
#   (1447, 1457, 'Observation', 'still born'),
#   (1461, 1471, 'Observation', 'died early'),
#   (1499, 1505, 'Observation', 'cancer')],
#  'doc_123': [(255, 261, 'FamilyMember', 'mother'),
#   (281, 294, 'Observation', 'p388 leukemia'),
#   (338, 348, 'Observation', 'blood clot'),
#   (363, 376, 'FamilyMember', 'maternal aunt'),
#   (420, 433, 'Observation', 'p388 leukemia'),
#   (464, 468, 'FamilyMember', 'aunt'),
#   (488, 500, 'Observation', 'brain cancer'),
#   (584, 604, 'FamilyMember', 'maternal grandmother'),
#   (645, 658, 'Observation', 'eating excess'),
#   (1084, 1092, 'FamilyMember', 'brothers'),
#   (1133, 1142, 'FamilyMember', 'daughters'),
#   (1168, 1171, 'FamilyMember', 'son')],
#  'doc_173': [(330, 336, 'FamilyMember', 'female'),
#   (418, 424, 'FamilyMember', 'sister'),
#   (442, 456, 'Observation', 'paramyloidosis'),
#   (590, 596, 'FamilyMember', 'sister'),
#   (641, 648, 'FamilyMember', 'brother'),
#   (666, 695, 'Observation', 'Infiltrating ductal carcinoma'),
#   (748, 754, 'FamilyMember', 'sister'),
#   (778, 793, 'Observation', 'type 2 diabetes'),
#   (967, 973, 'FamilyMember', 'sister'),
#   (1169, 1175, 'FamilyMember', 'mother'),
#   (1189, 1202, 'Observation', 'hairy tongues'),
#   (1237, 1242, 'Observation', 'tophi'),
#   (1249, 1255, 'FamilyMember', 'father'),
#   (1713, 1731, 'Observation', 'mental retardation'),
#   (1736, 1757, 'Observation', 'learning disabilities'),
#   (1782, 1803, 'Observation', 'leukemia thrombocytic'),
#   (1824, 1848, 'Observation', 'retinal artery occlusion')],
#  'doc_26': [(228, 235, 'FamilyMember', 'brother'),
#   (261, 267, 'FamilyMember', 'sister'),
#   (274, 280, 'FamilyMember', 'mother'),
#   (295, 307, 'Observation', 'hepatic coma'),
#   (342, 348, 'FamilyMember', 'father'),
#   (378, 384, 'FamilyMember', 'mother'),
#   (417, 437, 'FamilyMember', 'maternal grandmother'),
#   (442, 455, 'Observation', 'lactrodectism'),
#   (517, 537, 'FamilyMember', 'maternal grandfather'),
#   (556, 567, 'Observation', 'sirenomelia'),
#   (578, 584, 'Observation', 'smoker'),
#   (610, 624, 'FamilyMember', 'maternal uncle'),
#   (641, 654, 'FamilyMember', 'maternal aunt'),
#   (665, 685, 'FamilyMember', 'paternal grandmother'),
#   (719, 730, 'Observation', 'skin cancer'),
#   (795, 804, 'Observation', 'nonsmoker'),
#   (842, 862, 'FamilyMember', 'paternal grandfather'),
#   (879, 885, 'Observation', 'asthma'),
#   (921, 932, 'Observation', 'lip fissure'),
#   (1026, 1041, 'FamilyMember', 'paternal uncles'),
#   (1046, 1066, 'FamilyMember', 'seven paternal aunts'),
#   (1101, 1114, 'Observation', 'pancreas mass'),
#   (1390, 1408, 'Observation', 'mental retardation'),
#   (1410, 1431, 'Observation', 'learning disabilities'),
#   (1436, 1449, 'Observation', 'birth defects'),
#   (1474, 1495, 'Observation', 'multiple miscarriages'),
#   (1617, 1623, 'Observation', 'asthma')],
#  'doc_28': [(237, 245, 'FamilyMember', 'daughter'),
#   (265, 268, 'FamilyMember', 'son'),
#   (329, 335, 'FamilyMember', 'sister'),
#   (352, 359, 'FamilyMember', 'brother'),
#   (402, 408, 'FamilyMember', 'mother'),
#   (441, 454, 'FamilyMember', 'maternal aunt'),
#   (476, 496, 'Observation', 'fibrous cavernitides'),
#   (595, 601, 'FamilyMember', 'father'),
#   (633, 640, 'FamilyMember', 'brother'),
#   (675, 693, 'Observation', 'cystic fibrosis in'),
#   (751, 757, 'FamilyMember', 'nephew'),
#   (763, 771, 'Observation', 'diabetes'),
#   (1394, 1412, 'Observation', 'ulcerative colitis'),
#   (1416, 1437, 'Observation', 'ovarian endometriosis')],
#  'doc_7': [(222, 230, 'FamilyMember', 'Two sons'),
#   (263, 271, 'FamilyMember', 'daughter'),
#   (338, 344, 'FamilyMember', 'sister'),
#   (373, 386, 'Observation', 'enamel caries'),
#   (462, 479, 'Observation', 'oxatomide allergy'),
#   (492, 512, 'Observation', 'urticaria aggravated'),
#   (568, 578, 'Observation', 'malignancy'),
#   (704, 710, 'FamilyMember', 'sister'),
#   (726, 738, 'Observation', 'labium polyp'),
#   (748, 768, 'Observation', 'adherent pericardium'),
#   (794, 825, 'Observation', 'epiphysiolysis proximal femoral'),
#   (854, 860, 'FamilyMember', 'mother'),
#   (889, 902, 'Observation', 'indiana fever'),
#   (928, 951, 'Observation', 'pneumonitis toxoplasmal'),
#   (1028, 1059, 'Observation', 'otitis media acute seromucinous'),
#   (1092, 1106, 'FamilyMember', 'maternal uncle'),
#   (1139, 1154, 'Observation', 'syndromes fraxe'),
#   (1280, 1293, 'FamilyMember', 'maternal aunt'),
#   (1300, 1310, 'Observation', 'hypomnesia'),
#   (1456, 1470, 'Observation', 'pleura exudate'),
#   (1525, 1545, 'FamilyMember', 'maternal grandmother'),
#   (1589, 1597, 'Observation', 'sjogrens'),
#   (1698, 1704, 'Observation', 'canker'),
#   (1720, 1726, 'FamilyMember', 'father'),
#   (1761, 1784, 'Observation', 'sponge kidney medullary'),
#   (1849, 1862, 'FamilyMember', 'paternal aunt'),
#   (1905, 1913, 'Observation', 'mikulicz'),
#   (2002, 2008, 'Observation', 'corbus')],
#  'doc_105': [(317, 323, 'FamilyMember', 'father'),
#   (337, 349, 'Observation', 'heart issues'),
#   (354, 364, 'Observation', 'alcoholism'),
#   (378, 387, 'Observation', 'depressed'),
#   (470, 476, 'FamilyMember', 'mother'),
#   (490, 503, 'Observation', 'renal disease'),
#   (552, 564, 'Observation', 'heart murmur'),
#   (566, 577, 'Observation', 'alcohol use'),
#   (584, 587, 'Observation', 'DKA'),
#   (612, 648, 'Observation', 'carrier of leptomeningeal metastases'),
#   (655, 670, 'FamilyMember', 'maternal uncles'),
#   (675, 686, 'Observation', 'herpes iris'),
#   (693, 713, 'FamilyMember', 'maternal grandmother'),
#   (734, 740, 'Observation', 'cancer'),
#   (752, 764, 'Observation', 'heart attack'),
#   (782, 802, 'FamilyMember', 'maternal grandfather'),
#   (807, 822, 'Observation', 'type 2 diabetes'),
#   (836, 848, 'Observation', 'heavy smoker'),
#   (858, 867, 'Observation', 'allergies'),
#   (922, 937, 'Observation', 'genetic disease'),
#   (1054, 1063, 'Observation', 'allergies'),
#   (1067, 1087, 'Observation', 'rheumatoid arthritis'),
#   (1115, 1123, 'FamilyMember', 'siblings'),
#   (1134, 1156, 'FamilyMember', 'maternal half siblings'),
#   (1175, 1182, 'FamilyMember', 'sisters'),
#   (1189, 1192, 'Observation', 'DKA'),
#   (1335, 1362, 'Observation', 'cardiac problems infarction'),
#   (1408, 1417, 'FamilyMember', 'daughters'),
#   (1432, 1440, 'FamilyMember', 'daughter'),
#   (1445, 1455, 'Observation', 'hemophilia')],
#  'doc_152': [(438, 441, 'FamilyMember', 'son'),
#   (458, 466, 'FamilyMember', 'daughter'),
#   (518, 526, 'FamilyMember', 'brothers'),
#   (559, 565, 'FamilyMember', 'sister'),
#   (570, 586, 'Observation', 'sinus infections'),
#   (591, 598, 'Observation', 'malaria'),
#   (687, 693, 'FamilyMember', 'mother'),
#   (708, 724, 'Observation', 'sinus infections'),
#   (755, 759, 'FamilyMember', 'aunt'),
#   (779, 802, 'Observation', 'climactericum epileptic'),
#   (866, 872, 'Observation', 'cancer'),
#   (899, 911, 'FamilyMember', 'grandparents'),
#   (984, 992, 'FamilyMember', 'brothers'),
#   (1015, 1021, 'FamilyMember', 'father'),
#   (1026, 1037, 'Observation', 'brachyolmia'),
#   (1049, 1061, 'Observation', 'heavy smoker'),
#   (1075, 1096, 'FamilyMember', 'uncles (a half-uncle)'),
#   (1101, 1112, 'Observation', 'tonsillitis'),
#   (1117, 1128, 'Observation', 'cholangioma'),
#   (1140, 1152, 'Observation', 'heavy smoker'),
#   (1168, 1179, 'FamilyMember', 'grandmother'),
#   (1216, 1222, 'Observation', 'cancer')]}

# %%
assert(num_entities > 1785)

# %%
import pickle
with open(join(DIR, "entities_corrected.pkl"), 'wb') as pkl_file:
    pickle.dump(entities, pkl_file)

# %%
entities['doc_118']
# Out:
# [(212, 219, 'FamilyMember', 'brother'),
#  (237, 263, 'Observation', 'recurrent thyroid problems'),
#  (345, 351, 'FamilyMember', 'father'),
#  (345, 351, 'FamilyMember', 'father'),
#  (385, 391, 'FamilyMember', 'mother'),
#  (410, 422, 'Observation', 'hypertension')]
